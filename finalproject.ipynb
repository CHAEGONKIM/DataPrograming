# %% [markdown]
# <a href="https://colab.research.google.com/github/CHAEGONKIM/DataPrograming/blob/main/finalproject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 202084012 김채곤
#
# # 데이터수집
#
# ## *   남산도서관 대출도서 api를 이용해서 4월 대출건수 상위 100위 도서의 데이터
# ## *   yes24 홈페이지 웹크롤링을 통한 도서 가격

# %%
import requests
url = "http://data4library.kr/api/loanItemSrch?format=json&startDt=2023-04-01&endDt=2023-04-31&age=20&authKey=ccded6be47e141584432be6d180168312575252ecd42aff4aa67923a17c3e864"
r = requests.get(url)
data = r.json();
data
# Out:
# {'response': {'request': {'startDt': '2023-04-01',
#    'endDt': '2023-04-31',
#    'age': '20',
#    'pageNo': 1,
#    'pageSize': 200},
#   'resultNum': 200,
#   'numFound': 5000,
#   'docs': [{'doc': {'no': 1,
#      'ranking': '1',
#      'bookname': '물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기 ',
#      'authors': '룰루 밀러 지음 ;정지인 옮김',
#      'publisher': '곰출판',
#      'publication_year': '2021',
#      'isbn13': '9791189327156',
#      'addition_symbol': '03400',
#      'vol': '',
#      'class_no': '490.99',
#      'class_nm': '자연과학 > 동물학 > 동물학',
#      'loan_count': '444',
#      'bookImageURL': 'https://image.aladin.co.kr/product/28465/73/cover/k092835920_1.jpg',
#      'bookDtlUrl': 'https://data4library.kr/bookV?seq=6360937'}},
#    {'doc': {'no': 2,
#      'ranking': '2',
#      'bookname': '불편한 편의점 :김호연 장편소설 ',
#      'authors': '지은이: 김호연',
#      'publisher': '나무옆의자',
#      'publication_year': '2021',
#      'isbn13': '9791161571188',
# ...

# %%
books=[]
for d in data ['response']['docs']:
  books.append(d['doc'])
  books

# %%
import pandas as pd

books_df = pd.DataFrame(books)
books_df
# Out:
#       no ranking                                        bookname  \
# 0      1       1  물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기
# 1      2       2                              불편한 편의점 :김호연 장편소설
# 2      3       3                            달러구트 꿈 백화점.이미예 장편소설
# 3      4       4                     우리가 빛의 속도로 갈 수 없다면 :김초엽 소설
# 4      5       4                             지구 끝의 온실 :김초엽 장편소설
# ..   ...     ...                                             ...
# 195  196     194                                     거꾸로 읽는 세계사
# 196  197     197                                  더 좋은 삶을 위한 철학
# 197  198     197                                        호밀밭의 파수꾼
# 198  199     197                                        총, 균, 쇠
# 199  200     197                                  파친코 :이민진 장편소설
#
#                    authors            publisher publication_year  \
# 0         룰루 밀러 지음 ;정지인 옮김                  곰출판             2021
# ...

# %%
books_df.to_json('20s_best_book.json')

# %%
books_df.head()
# Out:
#    no ranking                                        bookname  \
# 0   1       1  물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기
# 1   2       2                              불편한 편의점 :김호연 장편소설
# 2   3       3                            달러구트 꿈 백화점.이미예 장편소설
# 3   4       4                     우리가 빛의 속도로 갈 수 없다면 :김초엽 소설
# 4   5       4                             지구 끝의 온실 :김초엽 장편소설
#
#             authors            publisher publication_year         isbn13  \
# 0  룰루 밀러 지음 ;정지인 옮김                  곰출판             2021  9791189327156
# 1          지은이: 김호연                나무옆의자             2021  9791161571188
# 2          지은이: 이미예                팩토리나인             2020  9791165341909
# 3          지은이: 김초엽                   허블             2019  9791190090018
# 4          지은이: 김초엽  Giant Books(자이언트북스)             2021  9791191824001
#
#   addition_symbol vol class_no          class_nm loan_count  \
# 0           03400       490.99  자연과학 > 동물학 > 동물학        444
# ...

# %%
books_df = books_df.drop('class_no',axis=1)
books_df
# Out:
#       no ranking                                        bookname  \
# 0      1       1  물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기
# 1      2       2                              불편한 편의점 :김호연 장편소설
# 2      3       3                            달러구트 꿈 백화점.이미예 장편소설
# 3      4       4                     우리가 빛의 속도로 갈 수 없다면 :김초엽 소설
# 4      5       4                             지구 끝의 온실 :김초엽 장편소설
# ..   ...     ...                                             ...
# 195  196     194                                     거꾸로 읽는 세계사
# 196  197     197                                  더 좋은 삶을 위한 철학
# 197  198     197                                        호밀밭의 파수꾼
# 198  199     197                                        총, 균, 쇠
# 199  200     197                                  파친코 :이민진 장편소설
#
#                    authors            publisher publication_year  \
# 0         룰루 밀러 지음 ;정지인 옮김                  곰출판             2021
# ...

# %%
books_df = books_df.drop('addition_symbol',axis=1)
books_df = books_df.drop('bookImageURL',axis=1)
books_df = books_df.drop('bookDtlUrl',axis=1)

# %%
books_df
# Out:
#       no ranking                                        bookname  \
# 0      1       1  물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기
# 1      2       2                              불편한 편의점 :김호연 장편소설
# 2      3       3                            달러구트 꿈 백화점.이미예 장편소설
# 3      4       4                     우리가 빛의 속도로 갈 수 없다면 :김초엽 소설
# 4      5       4                             지구 끝의 온실 :김초엽 장편소설
# ..   ...     ...                                             ...
# 195  196     194                                     거꾸로 읽는 세계사
# 196  197     197                                  더 좋은 삶을 위한 철학
# 197  198     197                                        호밀밭의 파수꾼
# 198  199     197                                        총, 균, 쇠
# 199  200     197                                  파친코 :이민진 장편소설
#
#                    authors            publisher publication_year  \
# 0         룰루 밀러 지음 ;정지인 옮김                  곰출판             2021
# ...

# %%
books_df = books_df.drop('vol',axis=1)

# %%
books_df
# Out:
#       no ranking                                        bookname  \
# 0      1       1  물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기
# 1      2       2                              불편한 편의점 :김호연 장편소설
# 2      3       3                            달러구트 꿈 백화점.이미예 장편소설
# 3      4       4                     우리가 빛의 속도로 갈 수 없다면 :김초엽 소설
# 4      5       4                             지구 끝의 온실 :김초엽 장편소설
# ..   ...     ...                                             ...
# 195  196     194                                     거꾸로 읽는 세계사
# 196  197     197                                  더 좋은 삶을 위한 철학
# 197  198     197                                        호밀밭의 파수꾼
# 198  199     197                                        총, 균, 쇠
# 199  200     197                                  파친코 :이민진 장편소설
#
#                    authors            publisher publication_year  \
# 0         룰루 밀러 지음 ;정지인 옮김                  곰출판             2021
# ...

# %%
# DH 키 에러 발생을 막기 위해
# https://stackoverflow.com/questions/38015537/python-requests-exceptions-sslerror-dh-key-too-small
import requests

requests.packages.urllib3.util.ssl_.DEFAULT_CIPHERS += 'HIGH:!DH:!aNULL'
try:
    requests.packages.urllib3.contrib.pyopenssl.DEFAULT_SSL_CIPHER_LIST += 'HIGH:!DH:!aNULL'
except AttributeError:
    # no pyopenssl support used / needed / available
    pass

# %%
import requests

isbn = 9791190090018      # '우리가 빛의 속도로 갈 수 없다면'의 ISBN
url = 'http://www.yes24.com/Product/Search?domain=BOOK&query={}'

r = requests.get(url.format(isbn))

# %%
print(r.text)
# Out:
# 	<!DOCTYPE html >
# 	<html lang="ko">
#
# <head>
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=utf-8" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title> 9791190090018 - 예스24</title>
#
# 	<meta name="title" content="예스24" />
# 	<meta name="description" content="YOUR EVERY STORY 문화 콘텐츠 플랫폼, 예스24" />
# 	<meta name="keywords" content="인터넷 서점, 온라인 쇼핑, 상품 추천, 쇼핑몰, 상품 검색, 도서 정보, 국내도서, 외국도서, 전자책, eBook, 이북, 크레마, 공연, 콘서트, 뮤지컬, 음반, 예매, DVD, 블루레이, 예스24, YES24, 교보문고, 알라딘" />
#
#
# 	<link title="YES24" rel="search" type="application/opensearchdescription+xml" href="//www.yes24.com/OpensearchDescription.xml">
#
# ...

# %%
from bs4 import BeautifulSoup

# %%
soup=BeautifulSoup(r.text,'html.parser')

# %%
prd_link = soup.find('a',attrs={'class':'gd_name'})
print(prd_link)
# Out:
# <a class="gd_name" href="/Product/Goods/74261416" onclick="setSCode('101_005_003_001');setGoodsClickExtraCodeHub('032', '9791190090018', '74261416', '0');">우리가 빛의 속도로 갈 수 없다면</a>

# %%
print(prd_link['href'])
# Out:
# /Product/Goods/74261416

# %%
url = 'http://www.yes24.com'+prd_link['href']
r= requests.get(url)
print(r.text)
# Out:
# 	<!DOCTYPE html >
# 	<html lang="ko">
#
# <head><link rel="canonical" href="https://www.yes24.com/Product/Goods/74261416"> <link rel="alternate" media="only screen and(max-width: 640px)"  href="https://m.yes24.com/Goods/Detail/74261416">
# 	<meta http-equiv="X-UA-Compatible" content="IE=Edge" />
# 	<meta http-equiv="Content-Type" content="text/html;charset=utf-8" />
# 	<meta http-equiv="Accept-CH" content="dpr, width, viewport-width, rtt, downlink, ect, UA, UA-Platform, UA-Arch, UA-Model, UA-Mobile, UA-Full-Version" />
# 	<meta http-equiv="Accept-CH-Lifetime" content="86400" />
# 	<meta name="referrer" content="unsafe-url" />
# 	<meta name="viewport" content="width=1170" />
#
# 	<title> 우리가 빛의 속도로 갈 수 없다면 - YES24 </title>
#
#
# <meta name="title" content="우리가 빛의 속도로 갈 수 없다면 - YES24"/>
# <meta name="author" content="김초엽" />
#
# ...

# %%
soup = BeautifulSoup(r.text,'html.parser')
prd_detail = soup.find('div',attrs={'class':'gd_infoTb'})
print(prd_detail)
# Out:
# <div class="gd_infoTb">
# <table summary="상품 가격정보 테이블">
# <colgroup>
# <col width="110"/>
# <col width="*"/>
# </colgroup>
# <caption>상품 가격정보</caption>
# <tbody>
# <!-- 개발 코맨트 : 음반/DVD/GIFT 는 "정가/판매가" 가 아니라 "판매가/할인가" 임 -->
# <tr>
# <th scope="row">
#                         정가
#                     </th>
# <td>
# <span class=""><em class="yes_m">14,000원</em></span>
# </td>
# </tr>
# <tr class="accentRow">
# <th scope="row">판매가</th>
# <td>
# <span class="nor_price"><em class="yes_m">12,600</em>원</span>  (10% 할인)
#                                     </td>
# </tr>
# <!-- 가격표시쿠폰 시작 -->
# <!-- 가격표시쿠폰 끝 -->
# <tr class="accentRow">
# <th scope="row">
#                         크레마머니<br/>최대혜택가
#                         <a class="bgYUI ico_comm ico_help" href="javascript:void(0)" onclick="openlayerNew('dPop_cremaPrice',this,true, 380);" title="도움말"></a>
# </th>
# <td>
# <span class="nor_price crema_price"><em class="yes_m">11,100</em>원</span>
# </td>
# </tr>
# <tr>
# <th scope="row">
# ...

# %%
prd_tr_list = prd_detail.find_all('tr')
print(prd_tr_list)
# Out:
# [<tr>
# <th scope="row">
#                         정가
#                     </th>
# <td>
# <span class=""><em class="yes_m">14,000원</em></span>
# </td>
# </tr>, <tr class="accentRow">
# <th scope="row">판매가</th>
# <td>
# <span class="nor_price"><em class="yes_m">12,600</em>원</span>  (10% 할인)
#                                     </td>
# </tr>, <tr class="accentRow">
# <th scope="row">
#                         크레마머니<br/>최대혜택가
#                         <a class="bgYUI ico_comm ico_help" href="javascript:void(0)" onclick="openlayerNew('dPop_cremaPrice',this,true, 380);" title="도움말"></a>
# </th>
# <td>
# <span class="nor_price crema_price"><em class="yes_m">11,100</em>원</span>
# </td>
# </tr>, <tr>
# <th scope="row">
#                     YES포인트 <a class="bgYUI ico_comm ico_help" href="javascript:void(0);" onclick="openlayerNew('dPop_yesPointIs',this,true, 408);" style="cursor:pointer" title="도움말"></a>
# </th>
# <td>
# <ul class="gd_infoLi">
# <li>
# <em class="yes_m"></em>700원 (5% 적립)
# ...

# %%
for tr in prd_tr_list:
    if tr.find('th').get_text().strip() == '정가':
        page_td = tr.find('td').get_text().strip()
        break

# %%
print(page_td)
# Out:
# 14,000원

# %%
def get_page_cnt(isbn):
    # Yes24 도서 검색 페이지 URL
    url = 'http://www.yes24.com/Product/Search?domain=BOOK&query={}'
    # URL에 ISBN을 넣어 HTML 가져옵니다.
    r = requests.get(url.format(isbn))
    soup = BeautifulSoup(r.text, 'html.parser')   # HTML 파싱
    # 검색 결과에서 해당 도서를 선택합니다.
    prd_info = soup.find('a', attrs={'class':'gd_name'})
    if prd_info == None:
        return ''
    # 도서 상세 페이지를 가져옵니다.
    url = 'http://www.yes24.com'+prd_info['href']
    r = requests.get(url)
    soup = BeautifulSoup(r.text, 'html.parser')
    # 상품 상세정보 div를 선택합니다.
    prd_detail = soup.find('div',attrs={'class':'gd_infoTb'})
    # 테이블에 있는 tr 태그를 가져옵니다.
    prd_tr_list = prd_detail.find_all('tr')
    # 쪽수가 들어 있는 th를 찾아 td에 담긴 값을 반환합니다.
    for tr in prd_tr_list:
      if tr.find('th').get_text().strip() == '정가':
        return tr.find('td').get_text().strip()

    return ''

# %%
get_page_cnt(9791189327156)
# Out:
# '17,000원'

# %%
top100_books = books_df.head(100)

# %%
top100_books
# Out:
#      no ranking                                        bookname  \
# 0     1       1  물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기
# 1     2       2                              불편한 편의점 :김호연 장편소설
# 2     3       3                            달러구트 꿈 백화점.이미예 장편소설
# 3     4       4                     우리가 빛의 속도로 갈 수 없다면 :김초엽 소설
# 4     5       4                             지구 끝의 온실 :김초엽 장편소설
# ..  ...     ...                                             ...
# 95   96      95                                 여름의 빌라 :백수린 소설
# 96   97      95                         오베라는 남자 :프레드릭 배크만 장편소설
# 97   98      98                             애쓰지 않아도 :최은영 짧은 소설
# 98   99      99                             대도시의 사랑법 :박상영 연작소설
# 99  100     100   기분이 태도가 되지 않게 :기분 따라 행동하다 손해 보는 당신을 위한 심리 수업
#
#                     authors            publisher publication_year  \
# 0          룰루 밀러 지음 ;정지인 옮김                  곰출판             2021
# 1                  지은이: 김호연                나무옆의자             2021
# ...

# %%
def get_page_cnt2(row):
    isbn = row['isbn13']
    return get_page_cnt(isbn)

# %%
page_price = top100_books.apply(get_page_cnt2, axis=1)
print(page_price)
# Out:
# 0     17,000원
# 1     14,000원
# 2     13,800원
# 3     14,000원
# 4     15,000원
#        ...
# 95    14,800원
# 96    16,800원
# 97    14,500원
# 98    14,000원
# 99    14,000원
# Length: 100, dtype: object

# %%
page_price.name = 'page_price'

# %%
top100_with_page_price = pd.merge(top100_books, page_price, 
                                 left_index=True, right_index=True)
top100_with_page_price
# Out:
#      no ranking                                        bookname  \
# 0     1       1  물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기
# 1     2       2                              불편한 편의점 :김호연 장편소설
# 2     3       3                            달러구트 꿈 백화점.이미예 장편소설
# 3     4       4                     우리가 빛의 속도로 갈 수 없다면 :김초엽 소설
# 4     5       4                             지구 끝의 온실 :김초엽 장편소설
# ..  ...     ...                                             ...
# 95   96      95                                 여름의 빌라 :백수린 소설
# 96   97      95                         오베라는 남자 :프레드릭 배크만 장편소설
# 97   98      98                             애쓰지 않아도 :최은영 짧은 소설
# 98   99      99                             대도시의 사랑법 :박상영 연작소설
# 99  100     100   기분이 태도가 되지 않게 :기분 따라 행동하다 손해 보는 당신을 위한 심리 수업
#
#                     authors            publisher publication_year  \
# 0          룰루 밀러 지음 ;정지인 옮김                  곰출판             2021
# 1                  지은이: 김호연                나무옆의자             2021
# ...

# %%
top100_with_page_price.to_csv('2023 4월 대출 top100 도서정보와 가격', index=False)

# %%
top100_df = top100_with_page_price.drop('authors',axis=1)

# %%
top100_df = top100_df.drop('publisher',axis=1)

# %%
top100_df = top100_df.drop('no',axis=1)

# %%
top100_df = top100_df.drop('class_nm',axis=1)

# %%
top100_df
# Out:
#    ranking                                        bookname publication_year  \
# 0        1  물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기              2021
# 1        2                              불편한 편의점 :김호연 장편소설              2021
# 2        3                            달러구트 꿈 백화점.이미예 장편소설              2020
# 3        4                     우리가 빛의 속도로 갈 수 없다면 :김초엽 소설              2019
# 4        4                             지구 끝의 온실 :김초엽 장편소설              2021
# ..     ...                                             ...              ...
# 95      95                                 여름의 빌라 :백수린 소설              2020
# 96      95                         오베라는 남자 :프레드릭 배크만 장편소설              2015
# 97      98                             애쓰지 않아도 :최은영 짧은 소설              2022
# 98      99                             대도시의 사랑법 :박상영 연작소설              2019
# 99     100   기분이 태도가 되지 않게 :기분 따라 행동하다 손해 보는 당신을 위한 심리 수업              2020
#
#            isbn13 loan_count page_price
# ...

# %%
top100_df = top100_df.rename(columns={'ranking': '순위',
                        'bookname': '책이름',
                        'publication_year': '출판년도',
                        'loan_count': '대출건수',
                       'page_price': '가격' })

# %%
top100_df
# Out:
#      순위                                             책이름  출판년도         isbn13  \
# 0     1  물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기   2021  9791189327156
# 1     2                              불편한 편의점 :김호연 장편소설   2021  9791161571188
# 2     3                            달러구트 꿈 백화점.이미예 장편소설   2020  9791165341909
# 3     4                     우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   2019  9791190090018
# 4     4                             지구 끝의 온실 :김초엽 장편소설   2021  9791191824001
# ..  ...                                             ...   ...            ...
# 95   95                                 여름의 빌라 :백수린 소설   2020  9788954673105
# 96   95                         오베라는 남자 :프레드릭 배크만 장편소설   2015  9791130605210
# 97   98                             애쓰지 않아도 :최은영 짧은 소설   2022  9788960907348
# 98   99                             대도시의 사랑법 :박상영 연작소설   2019  9788936437978
# 99  100   기분이 태도가 되지 않게 :기분 따라 행동하다 손해 보는 당신을 위한 심리 수업   2020  9788901243658
#
#    대출건수       가격
# 0   444  17,000원
# ...

# %% [markdown]
# # 데이터 정보

# %%
top100_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   순위      100 non-null    object
#  1   책이름     100 non-null    object
#  2   출판년도    100 non-null    object
#  3   isbn13  100 non-null    object
#  4   대출건수    100 non-null    object
#  5   가격      100 non-null    object
# dtypes: object(6)
# memory usage: 4.8+ KB

# %%
top100_df['대출건수'].min()
# Out:
# '121'

# %%
top100_df['대출건수'].max()
# Out:
# '444'

# %% [markdown]
# #    데이터 분석

# %%
top100_df
# Out:
#      순위                                             책이름  출판년도         isbn13  \
# 0     1  물고기는 존재하지 않는다 :상실, 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기   2021  9791189327156
# 1     2                              불편한 편의점 :김호연 장편소설   2021  9791161571188
# 2     3                            달러구트 꿈 백화점.이미예 장편소설   2020  9791165341909
# 3     4                     우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   2019  9791190090018
# 4     4                             지구 끝의 온실 :김초엽 장편소설   2021  9791191824001
# ..  ...                                             ...   ...            ...
# 95   95                                 여름의 빌라 :백수린 소설   2020  9788954673105
# 96   95                         오베라는 남자 :프레드릭 배크만 장편소설   2015  9791130605210
# 97   98                             애쓰지 않아도 :최은영 짧은 소설   2022  9788960907348
# 98   99                             대도시의 사랑법 :박상영 연작소설   2019  9788936437978
# 99  100   기분이 태도가 되지 않게 :기분 따라 행동하다 손해 보는 당신을 위한 심리 수업   2020  9788901243658
#
#    대출건수       가격
# 0   444  17,000원
# ...

# %% [markdown]
# # - 데이터 가공

# %%
top100_df = top100_df.applymap(lambda x: x.replace('원', '') if isinstance(x, str) else x)
top100_df = top100_df.applymap(lambda x: x.replace(',', '') if isinstance(x, str) else x)
top100_df['가격'] = top100_df['가격'].str.replace(' ', '')

# 비어 있는 값을 NaN으로 처리
top100_df['가격'] = top100_df['가격'].replace('', pd.NA)

# 숫자로 변환
top100_df['가격'] = pd.to_numeric(top100_df['가격'], errors='coerce')

# %%
top100_df
# Out:
#      순위                                            책이름  출판년도         isbn13  \
# 0     1  물고기는 존재하지 않는다 :상실 사랑 그리고 숨어 있는 삶의 질서에 관한 이야기   2021  9791189327156
# 1     2                             불편한 편의점 :김호연 장편소설   2021  9791161571188
# 2     3                           달러구트 꿈 백화점.이미예 장편소설   2020  9791165341909
# 3     4                    우리가 빛의 속도로 갈 수 없다면 :김초엽 소설   2019  9791190090018
# 4     4                            지구 끝의 온실 :김초엽 장편소설   2021  9791191824001
# ..  ...                                            ...   ...            ...
# 95   95                                여름의 빌라 :백수린 소설   2020  9788954673105
# 96   95                        오베라는 남자 :프레드릭 배크만 장편소설   2015  9791130605210
# 97   98                            애쓰지 않아도 :최은영 짧은 소설   2022  9788960907348
# 98   99                            대도시의 사랑법 :박상영 연작소설   2019  9788936437978
# 99  100  기분이 태도가 되지 않게 :기분 따라 행동하다 손해 보는 당신을 위한 심리 수업   2020  9788901243658
#
#     대출건수       가격
# 0    444  17000.0
# ...

# %%
top100_df['순위'] = top100_df['순위'].astype(int)
top100_df['출판년도'] = top100_df['출판년도'].astype(int)
top100_df['대출건수'] = top100_df['대출건수'].astype(int)
top100_df['가격'] = top100_df['가격'].astype(float)

# %%
import matplotlib.pyplot as plt

# %%
import sys
if 'google.colab' in sys.modules:
    # !echo 'debconf debconf/frontend select Noninteractive' | debconf-set-selections
    # 나눔 폰트를 설치합니다.
    # !sudo apt-get -qq -y install fonts-nanum
    import matplotlib.font_manager as fm
    font_files = fm.findSystemFonts(fontpaths=['/usr/share/fonts/truetype/nanum'])
    for fpath in font_files:
        fm.fontManager.addfont(fpath)

# %%
plt.rcParams['font.family'] = 'NanumGothic'

# %%
plt.rc('font', family='NanumBarunGothic', size=11)

# %%
plt.hist(top100_df['대출건수'],bins=100)
plt.show()

# %% [markdown]
# # **대출건수와 도서가격의 관계**

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 100

grouped_data = top100_df.groupby('가격')['대출건수'].sum()

pricedf = pd.DataFrame({'가격': grouped_data.index, '총 대출건수': grouped_data.values})
# 대출건수 데이터
loan_counts = pricedf['총 대출건수']
# 책 가격 데이터
book_prices = pricedf['가격']

# %%
plt.scatter(pricedf['가격'], pricedf['총 대출건수'])
plt.xlabel('가격')
plt.ylabel('출판년도')
plt.title('대출건수와 도서가격의 관계')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.plot(book_prices,loan_counts,marker='o', linestyle='-',color ='blue')
plt.xlabel('가격')
plt.ylabel('대출건수')
plt.title('대출건수와 도서가격의 관계')
plt.show()

# %% [markdown]
# # **대출건수와 출판년도의 관계**

# %%
import matplotlib.pyplot as plt
plt.rcParams['figure.dpi'] = 100

grouped_data = top100_df.groupby('출판년도')['대출건수'].sum()

new_data = pd.DataFrame({'출판년도': grouped_data.index, '총 대출건수': grouped_data.values})
# 대출건수 데이터
loan_counts = new_data['총 대출건수']
# 책 가격 데이터
year = new_data['출판년도']

# %%
plt.scatter(new_data['출판년도'], new_data['총 대출건수'])
plt.xlabel('출판년도')
plt.ylabel('대출건수')
plt.title('대출건수와 출판년도의 관계')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
fig, ax = plt.subplots(figsize=(10, 8))
ax.scatter(new_data['출판년도'], new_data['총 대출건수'])
ax.set_title('대출건수와 출판년도의 관계')
plt.show()

# %%
plt.plot(year, loan_counts, marker='o', linestyle='-',color='red')
plt.title('대출건수와 출판년도의 관계')
plt.xlabel('출판년도')
plt.ylabel('대출건수')
plt.show()

# %% [markdown]
# ## 시사점
#
# ## * 남산도서관 4월 대출건수 상위 100권의 도서에서 대출건수와 도서가격의 관계에서는 양의 상관관계가 있다고 말할 수는 없습니다.그러나 위의 그래프를 통해서 도서의 가격이 14000원과 16000원 사이의 도서들이 대출빈도가 높다고 볼 수 있습니다.
# ## *   남산도서관 4월 대출건수 상위 100권의 도서에서 대출건수와 출판년도의 관계에서는 양의 상관관계가 있어보이며, 비교적 최근 출판된 도서의 경우 대출건수가 높은 것으로 보아 도서관 이용자들을 위해 최신 도서들을 구비한다면, 보다 많은 이용자들이 도서를 대출할 것으로 보입니다.
